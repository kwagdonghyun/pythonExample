# %%
import re

txt = "The rain in Spain"

# %%
x = re.search("^The.*Spain$", txt)
print(x)
# Out:
# <re.Match object; span=(0, 17), match='The rain in Spain'>

# %%
print(re.findall("ai", txt))
print(re.findall("Portugal", txt))
# Out:
# ['ai', 'ai']
# []

# %%
result = re.search("\s", txt)
print(result.start())
# Out:
# 3

# %%
print(re.split("\s", txt))
print(re.split("\s", txt, 1))
# Out:
# ['The', 'rain', 'in', 'Spain']
# ['The', 'rain in Spain']
# C:\Users\admin\AppData\Local\Temp\ipykernel_20220\4140719904.py:2: DeprecationWarning: 'maxsplit' is passed as positional argument
#   print(re.split("\s", txt, 1))

# %%
print(re.sub("\s", "9", txt))
print(re.sub("\s", "9", txt, 2))
# Out:
# The9rain9in9Spain
# The9rain9in Spain
# C:\Users\admin\AppData\Local\Temp\ipykernel_20220\3017221125.py:2: DeprecationWarning: 'count' is passed as positional argument
#   print(re.sub("\s", "9", txt, 2))

# %%
match = re.search(r"\bS\w+", txt)

print(match.span())
print(match.string)
print(match.group())
# Out:
# (12, 17)
# The rain in Spain
# Spain
